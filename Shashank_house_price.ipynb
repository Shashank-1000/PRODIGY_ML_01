# %%
import pandas as pd
from sklearn.metrics import mean_squared_error,r2_score

# %%
df= pd.read_csv('train.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
features= ["GrLivArea","BedroomAbvGr","FullBath"]

# %%
x=df[features]

# %%
y= df["SalePrice"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size= 0.2, random_state=40)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(x_test)

# %%
error = mean_squared_error(y_test, y_pred)

# %%
r2 = r2_score(y_test, y_pred)

# %%
print("mean_squared_error",error)
print("r2_score",r2)
# Out:
# mean_squared_error 2006326078.4218316
# r2_score 0.611376188591825

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae= mean_absolute_error(y_test, y_pred)

# %%
print("mean_absolute_error",mae)
# Out:
# mean_absolute_error 31843.53492825177

# %%
from matplotlib import pyplot as plt

# %%
#plotting predictions now
plt.scatter(y_test, y_pred)
plt.xlabel("Actual prices")
plt.ylabel("Predicted prices")
plt.title("Comparison of prices")
plt.show()

# %%
new_data= pd.DataFrame({'GrLivArea': [2000], 'BedroomAbvGr': [3],'FullBath': [2]})
predicted_price = model.predict(new_data)
print(f'Predicted Price : {predicted_price[0]}')
# Out:
# Predicted Price : 244593.48754399215

# %%
new_data= pd.DataFrame({'GrLivArea': [2000], 'BedroomAbvGr': [2],'FullBath': [1]})
predicted_price = model.predict(new_data)
print(f'Predicted Price : {predicted_price[0]}')
# Out:
# Predicted Price : 240305.38558852192

# %%
new_data= pd.DataFrame({'GrLivArea': [2500], 'BedroomAbvGr': [4],'FullBath': [2]})
predicted_price = model.predict(new_data)
print(f'Predicted Price : {predicted_price[0]}')
# Out:
# Predicted Price : 271311.85813312256
